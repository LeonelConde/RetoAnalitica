# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv("covid19_tweets.csv")
df=pd.DataFrame(data)
df
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser                   NaN
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3      #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4      🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
# ...                                                  ...                  ...
# 74431            The only things I collect are memories.  2010-09-24 02:01:15
# 74432  Law Prof @DickinsonLaw & Entrepreneur | Crypto...  2013-05-14 20:15:24
# 74433  Our mission is to provide news and perspective...  2018-02-04 12:36:42
# 74434  Reagan conservative and attorney raised in the...  2014-02-18 03:46:28
# 74435  My spectral decomposition has a significant da...  2016-12-19 19:55:00
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 0                 624           950            18775          False
# 1                2253          1677               24           True
# 2                9275          9525             7254          False
# 3                 197           987             1488          False
# 4              101009           168              101          False
# ...               ...           ...              ...            ...
# 74431              85           586             1902          False
# 74432            4289          1066            53569          False
# 74433            1413           102               16          False
# 74434            2554          1733           129104          False
# 74435             310          1748            60133          False
#
#                       date                                               text  \
# 0      2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1      2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2      2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3      2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 4      2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
# ...                    ...                                                ...
# 74431  2020-08-04 03:13:29  So far this summer I have filled up my lawn mo...
# 74432  2020-08-04 03:13:26  ICYMI: REPLAY: #TechIntersect🧩 #16: Isaiah "@B...
# 74433  2020-08-04 03:13:22  Community workers in Tianshan District of Urum...
# 74434  2020-08-04 03:13:19  If only we had a responsible media to warn us ...
# 74435  2020-08-04 03:13:15  MAGA: #COVID19 is just a cold &amp; it'd be go...
#
#                                       hashtags               source  \
# 0                                          NaN   Twitter for iPhone
# 1                                          NaN  Twitter for Android
# 2                                  ['COVID19']  Twitter for Android
# 3                                  ['COVID19']   Twitter for iPhone
# 4            ['CoronaVirusUpdates', 'COVID19']  Twitter for Android
# ...                                        ...                  ...
# 74431            ['COVID19', 'QuarantineLife']   Twitter for iPhone
# 74432  ['TechIntersect', 'Bitcoin', 'COVID19']      Twitter Web App
# 74433                    ['China', 'Xinjiang']      Twitter Web App
# 74434                              ['COVID19']   Twitter for iPhone
# 74435       ['COVID19', 'Hydroxycholoroquine']  Twitter for Android
#
#        is_retweet
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 74431       False
# 74432       False
# 74433       False
# 74434       False
# 74435       False
#
# [74436 rows x 13 columns]

# %%
df['user_name'].value_counts()
# Out:
# GlobalPandemic.NET     312
# covidnews.ch           239
# Coronavirus Updates    181
# Open Letters           177
# Hindustan Times        125
#                       ...
# Dotun Aboaba             1
# Audrey Tan               1
# Gina Guerrero            1
# Matthew Harms            1
# Payal Raj                1
# Name: user_name, Length: 44853, dtype: int64

# %%
# Limpiamos nuestro código para que este libre de Nan's y los reemplazamos con espacio
df.fillna(" ")
# Out:
#                       user_name         user_location  \
# 0                        ᏉᎥ☻լꂅϮ            astroworld
# 1                 Tom Basile 🇺🇸          New York, NY
# 2               Time4fisticuffs      Pewee Valley, KY
# 3                   ethel mertz  Stuck in the Middle
# 4                      DIPR-J&K     Jammu and Kashmir
# ...                         ...                   ...
# 74431             Laura Wolfrom         Lexington, KY
# 74432  Professor Tonya M. Evans         😷 #stayathome
# 74433        People's Daily app           北京, 中华人民共和国
# 74434                     M0ser
# 74435    Your Friend & Sabre ⚔️           Chicago, IL
#
#                                         user_description         user_created  \
# 0      wednesday addams as a disney princess keepin i...  2017-05-26 05:46:42
# 1      Husband, Father, Columnist & Commentator. Auth...  2009-04-16 20:06:23
# 2      #Christian #Catholic #Conservative #Reagan #Re...  2009-02-28 18:57:41
# 3      #Browns #Indians #ClevelandProud #[]_[] #Cavs ...  2019-03-07 01:45:06
# 4      🖊️Official Twitter handle of Department of Inf...  2017-02-12 06:45:15
# ...                                                  ...                  ...
# 74431            The only things I collect are memories.  2010-09-24 02:01:15
# 74432  Law Prof @DickinsonLaw & Entrepreneur | Crypto...  2013-05-14 20:15:24
# 74433  Our mission is to provide news and perspective...  2018-02-04 12:36:42
# 74434  Reagan conservative and attorney raised in the...  2014-02-18 03:46:28
# 74435  My spectral decomposition has a significant da...  2016-12-19 19:55:00
#
#        user_followers  user_friends  user_favourites  user_verified  \
# 0                 624           950            18775          False
# 1                2253          1677               24           True
# 2                9275          9525             7254          False
# 3                 197           987             1488          False
# 4              101009           168              101          False
# ...               ...           ...              ...            ...
# 74431              85           586             1902          False
# 74432            4289          1066            53569          False
# 74433            1413           102               16          False
# 74434            2554          1733           129104          False
# 74435             310          1748            60133          False
#
#                       date                                               text  \
# 0      2020-07-25 12:27:21  If I smelled the scent of hand sanitizers toda...
# 1      2020-07-25 12:27:17  Hey @Yankees @YankeesPR and @MLB - wouldn't it...
# 2      2020-07-25 12:27:14  @diane3443 @wdunlap @realDonaldTrump Trump nev...
# 3      2020-07-25 12:27:10  @brookbanktv The one gift #COVID19 has give me...
# 4      2020-07-25 12:27:08  25 July : Media Bulletin on Novel #CoronaVirus...
# ...                    ...                                                ...
# 74431  2020-08-04 03:13:29  So far this summer I have filled up my lawn mo...
# 74432  2020-08-04 03:13:26  ICYMI: REPLAY: #TechIntersect🧩 #16: Isaiah "@B...
# 74433  2020-08-04 03:13:22  Community workers in Tianshan District of Urum...
# 74434  2020-08-04 03:13:19  If only we had a responsible media to warn us ...
# 74435  2020-08-04 03:13:15  MAGA: #COVID19 is just a cold &amp; it'd be go...
#
#                                       hashtags               source  \
# 0                                                Twitter for iPhone
# 1                                               Twitter for Android
# 2                                  ['COVID19']  Twitter for Android
# 3                                  ['COVID19']   Twitter for iPhone
# 4            ['CoronaVirusUpdates', 'COVID19']  Twitter for Android
# ...                                        ...                  ...
# 74431            ['COVID19', 'QuarantineLife']   Twitter for iPhone
# 74432  ['TechIntersect', 'Bitcoin', 'COVID19']      Twitter Web App
# 74433                    ['China', 'Xinjiang']      Twitter Web App
# 74434                              ['COVID19']   Twitter for iPhone
# 74435       ['COVID19', 'Hydroxycholoroquine']  Twitter for Android
#
#        is_retweet
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
# ...           ...
# 74431       False
# 74432       False
# 74433       False
# 74434       False
# 74435       False
#
# [74436 rows x 13 columns]

# %%
# Crearemos otro DataFrame con la información relevante para nuestro reto
new_df=df[['user_name','user_followers', 'user_favourites','text','user_verified']].copy()

# %%
new_df
# Out:
#                       user_name  user_followers  user_favourites  \
# 0                        ᏉᎥ☻լꂅϮ             624            18775
# 1                 Tom Basile 🇺🇸            2253               24
# 2               Time4fisticuffs            9275             7254
# 3                   ethel mertz             197             1488
# 4                      DIPR-J&K          101009              101
# ...                         ...             ...              ...
# 74431             Laura Wolfrom              85             1902
# 74432  Professor Tonya M. Evans            4289            53569
# 74433        People's Daily app            1413               16
# 74434                     M0ser            2554           129104
# 74435    Your Friend & Sabre ⚔️             310            60133
#
#                                                     text  user_verified
# 0      If I smelled the scent of hand sanitizers toda...          False
# 1      Hey @Yankees @YankeesPR and @MLB - wouldn't it...           True
# 2      @diane3443 @wdunlap @realDonaldTrump Trump nev...          False
# 3      @brookbanktv The one gift #COVID19 has give me...          False
# 4      25 July : Media Bulletin on Novel #CoronaVirus...          False
# ...                                                  ...            ...
# 74431  So far this summer I have filled up my lawn mo...          False
# 74432  ICYMI: REPLAY: #TechIntersect🧩 #16: Isaiah "@B...          False
# 74433  Community workers in Tianshan District of Urum...          False
# 74434  If only we had a responsible media to warn us ...          False
# 74435  MAGA: #COVID19 is just a cold &amp; it'd be go...          False
#
# [74436 rows x 5 columns]

# %%
new_df.fillna(" ")
# Out:
#                       user_name  user_followers  user_favourites  \
# 0                        ᏉᎥ☻լꂅϮ             624            18775
# 1                 Tom Basile 🇺🇸            2253               24
# 2               Time4fisticuffs            9275             7254
# 3                   ethel mertz             197             1488
# 4                      DIPR-J&K          101009              101
# ...                         ...             ...              ...
# 74431             Laura Wolfrom              85             1902
# 74432  Professor Tonya M. Evans            4289            53569
# 74433        People's Daily app            1413               16
# 74434                     M0ser            2554           129104
# 74435    Your Friend & Sabre ⚔️             310            60133
#
#                                                     text  user_verified
# 0      If I smelled the scent of hand sanitizers toda...          False
# 1      Hey @Yankees @YankeesPR and @MLB - wouldn't it...           True
# 2      @diane3443 @wdunlap @realDonaldTrump Trump nev...          False
# 3      @brookbanktv The one gift #COVID19 has give me...          False
# 4      25 July : Media Bulletin on Novel #CoronaVirus...          False
# ...                                                  ...            ...
# 74431  So far this summer I have filled up my lawn mo...          False
# 74432  ICYMI: REPLAY: #TechIntersect🧩 #16: Isaiah "@B...          False
# 74433  Community workers in Tianshan District of Urum...          False
# 74434  If only we had a responsible media to warn us ...          False
# 74435  MAGA: #COVID19 is just a cold &amp; it'd be go...          False
#
# [74436 rows x 5 columns]

# %%
new_df.describe()
# Out:
#        user_followers  user_favourites
# count    7.443600e+04     7.443600e+04
# mean     1.059513e+05     1.529747e+04
# std      8.222900e+05     4.668971e+04
# min      0.000000e+00     0.000000e+00
# 25%      1.660000e+02     2.200000e+02
# 50%      9.600000e+02     1.927000e+03
# 75%      5.148000e+03     1.014800e+04
# max      1.389284e+07     2.047197e+06

# %%
print(new_df.groupby('user_verified').size())
# Out:
# user_verified
# False    65082
# True      9354
# dtype: int64

# %%
df.drop(['user_location','user_description','user_created','user_friends','user_verified','date','text','hashtags','source','is_retweet'],1).hist()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.cluster import KMeans
from sklearn.metrics import pairwise_distances_argmin_min

# %matplotlib inline
from mpl_toolkits.mplot3d import Axes3D
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
sb.pairplot(new_df.dropna(), hue='user_verified',height=4,vars=["user_followers","user_favourites"],kind='scatter')
